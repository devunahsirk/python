# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('ElectricCarData_Clean.csv')
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
df.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000

# %%
df['Charge']= df['Range_Km']*df['Efficiency_WhKm']
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro  Charge
# 0  Type 2 CCS      Sedan       D      5      55480   72450
# ...

# %%
a=np.arange(1,104)

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Optionally, drop rows with missing values
numeric_df = numeric_df.dropna()

# Now create the heatmap
plt.figure(figsize=(15, 8))
heatmap = sb.heatmap(numeric_df.corr(), linewidths=1, linecolor='white', annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sb.pairplot(df)

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_792d9_row0_col0, #T_792d9_row1_col1, #T_792d9_row2_col2, #T_792d9_row3_col3, #T_792d9_row4_col4, #T_792d9_row5_col5, #T_792d9_row6_col6, #T_792d9_row7_col7, #T_792d9_row8_col8, #T_792d9_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_792d9_row0_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_792d9_row0_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_792d9_row0_col3, #T_792d9_row8_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_792d9_row0_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_792d9_row0_col5, #T_792d9_row0_col6, #T_792d9_row2_col3, #T_792d9_row2_col9, #T_792d9_row3_col2, #T_792d9_row4_col7, #T_792d9_row4_col8, #T_792d9_row6_col0, #T_792d9_row6_col1, #T_792d9_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_792d9_row0_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_792d9_row0_col8 {
# ...

# %%
# Select only numeric columns for the correlation matrix
numeric_df = df.select_dtypes(include=[np.number])

# Compute the correlation matrix
corr = numeric_df.corr()

# Visualize the correlation matrix with a background gradient
plt.figure(figsize=(15, 8))
heatmap = sb.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=1, linecolor='white')
plt.title('Correlation Matrix Heatmap')
plt.show()
