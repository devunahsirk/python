# %% [markdown]
# ## Loading datas into pandas

# %%
import pandas as pd
#df=pd.read_csv('pokemon_data.csv')
df = pd.read_csv('pokemon_data.csv', index_col=0)
df.head(3) # print 1st 3 rows
df.tail(3) #print last 3 rows
# Out:
#                     Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 720      130     70           6       True
# 720      130     80           6       True
# 721       90     70           6       True

# %%
#Note: To separate csv file like [1,Boy,Krishanu,24] we can use : df=pd.read_csv('filename.csv', delimiter='\t')

# %% [markdown]
# ## Read headers

# %%
print(df.columns)
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## Read each columns

# %%
#df['Name']
#df['Name'][0:5]
#df.Name[0:5]
#df.Name
df[['Name','Attack','HP']]
# Out:
#                       Name  Attack  HP
# #
# 1                Bulbasaur      49  45
# 2                  Ivysaur      62  60
# 3                 Venusaur      82  80
# 3    VenusaurMega Venusaur     100  80
# 4               Charmander      52  39
# ..                     ...     ...  ..
# 719                Diancie     100  50
# 719    DiancieMega Diancie     160  50
# 720    HoopaHoopa Confined     110  80
# 720     HoopaHoopa Unbound     160  80
# 721              Volcanion     110  80
#
# [800 rows x 3 columns]

# %% [markdown]
# ## Read each row

# %%
print(df.iloc[4]) # for each row
#print(df.iloc[1:4]) # for multiple row
# Out:
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %% [markdown]
# ## Read specific column and row

# %%
print(df.iloc[2,1])
# Out:
# Grass

# %%
#to iterate each row with index
#for index,row in df.iterrows():
 #   print(index,row)

# %%
df.loc[df['Type 1']=='Fire'] # Read based on specific value of column
# Out:
#                           Name Type 1    Type 2   HP  Attack  Defense  \
# #
# 4                   Charmander   Fire       NaN   39      52       43
# 5                   Charmeleon   Fire       NaN   58      64       58
# 6                    Charizard   Fire    Flying   78      84       78
# 6    CharizardMega Charizard X   Fire    Dragon   78     130      111
# 6    CharizardMega Charizard Y   Fire    Flying   78     104       78
# 37                      Vulpix   Fire       NaN   38      41       40
# 38                   Ninetales   Fire       NaN   73      76       75
# 58                   Growlithe   Fire       NaN   55      70       45
# 59                    Arcanine   Fire       NaN   90     110       80
# 77                      Ponyta   Fire       NaN   50      85       55
# 78                    Rapidash   Fire       NaN   65     100       70
# 126                     Magmar   Fire       NaN   65      95       57
# ...

# %%
merge_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')] # Read data merged values of column
merge_df
# Out:
#                       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur  Grass  Poison   45      49       49       65
# 2                  Ivysaur  Grass  Poison   60      62       63       80
# 3                 Venusaur  Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 43                  Oddish  Grass  Poison   45      50       55       75
# 44                   Gloom  Grass  Poison   60      65       70       85
# 45               Vileplume  Grass  Poison   75      80       85      110
# 69              Bellsprout  Grass  Poison   50      75       35       70
# 70              Weepinbell  Grass  Poison   65      90       50       85
# 71              Victreebel  Grass  Poison   80     105       65      100
# 315                Roselia  Grass  Poison   50      60       45      100
# 406                  Budew  Grass  Poison   40      30       35       50
# ...

# %%
#To count he total number of above values
total_count = df.loc[df['Type 1'] == 'Fire'].shape[0]
print("Total count:", total_count)
# Out:
# Total count: 52

# %% [markdown]
# ## Sorting/ Describing data

# %%
df.sort_values(['Type 1','HP'],ascending=False) # Value of both are False
# Out:
#           Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 321    Wailord  Water     NaN  170      90       45       90       45     60
# 594  Alomomola  Water     NaN  165      75       80       40       45     65
# 131     Lapras  Water     Ice  130      85       80       85       95     60
# 134   Vaporeon  Water     NaN  130      65       60      110       95     65
# 320    Wailmer  Water     NaN  130      70       35       70       35     60
# ..         ...    ...     ...  ...     ...      ...      ...      ...    ...
# 290    Nincada    Bug  Ground   31      45       90       30       30     40
# 415     Combee    Bug  Flying   30      30       42       30       42     70
# 543   Venipede    Bug  Poison   30      45       59       30       39     57
# 213    Shuckle    Bug    Rock   20      10      230       10      230      5
# 292   Shedinja    Bug   Ghost    1      90       45       30       30     40
#
#      Generation  Legendary
# #
# ...

# %%
df.sort_values(['Type 1','HP'],ascending=[0,1]) # It means the value of Type 1 is false and the value of HP is True
# Out:
#                         Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 129                 Magikarp  Water       NaN  20      10       55       15
# 349                   Feebas  Water       NaN  20      15       20       10
# 90                  Shellder  Water       NaN  30      65      100       45
# 98                    Krabby  Water       NaN  30     105       90       25
# 116                   Horsea  Water       NaN  30      40       70       70
# ..                       ...    ...       ...  ..     ...      ...      ...
# 214  HeracrossMega Heracross    Bug  Fighting  80     185      115       40
# 617                 Accelgor    Bug       NaN  80      70       40      100
# 666                 Vivillon    Bug    Flying  80      52       50       90
# 637                Volcarona    Bug      Fire  85      60       65      135
# 469                  Yanmega    Bug    Flying  86      76       86      116
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# ## Making changes to the data

# %%
#Adding a new column
df['Total']= df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Sp. Def']
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# #
# ...

# %%
#Deleting a column
df = df.drop(['Total'], axis=1) # Axis 1 is columns ---> and axis 0 is rows ↓
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# ## Saving our data

# %%
#df.to_csv('filename.csv')
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# ## Filtering the data

# %%
filter_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
filter_df
# Out:
#                       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 3                 Venusaur  Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 45               Vileplume  Grass  Poison   75      80       85      110
# 71              Victreebel  Grass  Poison   80     105       65      100
# 591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 3        100     80           1      False
# 3        120     80           1      False
# 45        90     50           1      False
# 71        70     70           1      False
# 591       80     30           5      False
